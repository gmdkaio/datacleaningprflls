# %%
import pandas as pd 

# Carregar planinhas Excel - sheet name 'Propostas'
df1 = pd.read_excel('../data/propostajpn.xlsx', sheet_name='Propostas')
df2 = pd.read_excel('../data/propostamuralha.xlsx', sheet_name='Propostas')

# Coluna local pra diferenciar as tabelas
df1['local'] = 'JPN'
df2['local'] = 'Muralha'

df1.head()

# %%
# Concatenar os dois DataFrames
df = pd.concat([df1, df2], ignore_index=True)
df.to_excel('propostas_concatenadas.xlsx', index=False)
